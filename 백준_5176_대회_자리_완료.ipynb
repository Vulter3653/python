# %% [markdown]
# <a href="https://colab.research.google.com/github/Vulter3653/python/blob/main/%EB%B0%B1%EC%A4%80_5176_%EB%8C%80%ED%9A%8C_%EC%9E%90%EB%A6%AC_%EC%99%84%EB%A3%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for _ in range(int(input())):
  a,b = map(int,input().split())
  uni = []
  for _ in range(a):
    uni.append(int(input()))
  print(len(uni)-len(list(set(uni))))
# Out:
# 3
# 4 1
# 1
# 1
# 1
# 1
# 3
# 4 4
# 1
# 2
# 3
# 4
# 0
# 4 4
# 1
# 4
# 1
# 4
# 2
