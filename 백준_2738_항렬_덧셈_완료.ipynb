# %% [markdown]
# <a href="https://colab.research.google.com/github/Vulter3653/python/blob/main/%EB%B0%B1%EC%A4%80_2738_%ED%95%AD%EB%A0%AC_%EB%8D%A7%EC%85%88_%EC%99%84%EB%A3%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# N,M = map(int,input().split())
N = 1
M = 1

A = []
B = []

for _ in range(N):
  A.append(list(map(int,input().split())))
  print(A)

for _ in range(M):
  B.append(list(map(int,input().split())))
  print(B)

for x in range(N):
  for y in range(M):
    print(A[x][y]+B[x][y], end=" ")
  print(" ")
# Out:
# 1
# [[1]]
# 2
# [[2]]
# 3

# %%
a = []
for x in range(3):
  a.append(list(map(int,input().split())))
  print(a)
# Out:
# 1 1 1
# [[1, 1, 1]]
# 2 2 2
# [[1, 1, 1], [2, 2, 2]]
# 0 1 0
# [[1, 1, 1], [2, 2, 2], [0, 1, 0]]

# %%
N,M = map(int,input().split())

A = []
B = []

for _ in range(N):
  A.append(list(map(int,input().split())))

for _ in range(M):
  B.append(list(map(int,input().split())))

for x in range(N):
  for y in range(M):
    print(A[x][y]+B[x][y], end=" ")
  print("")
# Out:
# 3 3
# 1 1 1
# 2 2 2
# 0 1 0
# 3 3 3
# 4 4 4
# 5 5 100
# 4 4 4
# 6 6 6
# 5 6 100

# %%
# EOFError 발생함
A = []
B = []

N,M = map(int,input().split())

for _ in range(N):
  A.append(list(map(int,input().split())))

for _ in range(M):
  B.append(list(map(int,input().split())))

for x in range(N):
  for y in range(M):
    print(A[x][y]+B[x][y], end=" ")
  print()

# %%
# 이건 되네..?
#출처: https://develop247.tistory.com/93#google_vignette [ImJay:티스토리]

A, B = [], []

N, M = map(int, input().split())

for row in range(N):
    row = list(map(int, input().split()))
    A.append(row)

for row in range(N):
    row = list(map(int, input().split()))
    B.append(row)

# map 함수는 맵 객체(map object)를 반환하므로, row에는 list 형태로 받아주어야 한다. 맵 객체는 이터레이터이기 때문에 다대다 관계에서는 list가 생략이 가능하지만,
# 일대다 관계에서 map 함수는 list 를 통해 값을 확인할 수 있다.
# 저 리스트가 문제구나
for row in range(N):
    for col in range(M):
        print(A[row][col] + B[row][col], end=' ')
    print()
# Out:
# 3 3
# 1 1 1
# 2 2 2
# 0 1 0
# 3 3 3
# 4 4 4
# 5 5 100
# 4 4 4
# 6 6 6
# 5 6 100

# %%
# EOFError 이건 또 왜 안되는가 대체
A = []
B = []

N,M = map(int,input().split())

for x in range(N):
  row = list(map(int,input().split()))
  A.append(row)

for x in range(M):
  row = list(map(int,input().split()))
  B.append(row)

for x in range(N):
  for y in range(M):
    print(A[x][y]+B[x][y], end=" ")
  print()
# Out:
# 3 3
# 1 1 1
# 2 2 2
# 0 1 0
# 3 3 3
# 4 4 4
# 5 5 100
# 4 4 4
# 6 6 6
# 5 6 100

# %%
# 이건 통과
# 두 번째 입력 받을 때, N이 아니라 M을 넣음
A = []
B = []

N,M = map(int,input().split())

for _ in range(N):
  A.append(list(map(int,input().split())))

for _ in range(N):
  B.append(list(map(int,input().split())))

for x in range(N):
  for y in range(M):
    print(A[x][y]+B[x][y], end=" ")
  print()
