# %% [markdown]
# <a href="https://colab.research.google.com/github/Vulter3653/python/blob/main/%EB%B0%B1%EC%A4%80_3460_%EC%9D%B4%EC%A7%84%EC%88%98_%EC%99%84%EB%A3%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for x in range(int(input())):
  a = int(input())
  b = []
  while a != 0:
    b.append(a%2)
    a = a//2

  for x in range(len(b)):
    if b[x] == 1:
      print(x,end=" ")
# Out:
# 1
# 13
# 0 2 3
