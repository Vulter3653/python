# %% [markdown]
# <a href="https://colab.research.google.com/github/Vulter3653/python/blob/main/Baekjoon_2075_N%EB%B2%88%EC%A7%B8_%ED%81%B0_%EC%88%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import heapq

N = int(input())
q = []
for _ in range(N):
    for n in map(int, input().split()):
        heapq.heappush(q, (-n, n))
        print(q)
    q = heapq.nsmallest(N, q)
    print(q)
heapq.heapify(q)
print(q[N-1][1])
# Out:
# 5
# 12 7 9 15 5
# [(-12, 12)]
# [(-12, 12), (-7, 7)]
# [(-12, 12), (-7, 7), (-9, 9)]
# [(-15, 15), (-12, 12), (-9, 9), (-7, 7)]
# [(-15, 15), (-12, 12), (-9, 9), (-7, 7), (-5, 5)]
# [(-15, 15), (-12, 12), (-9, 9), (-7, 7), (-5, 5)]
# 13 8 11 19 6
# [(-15, 15), (-12, 12), (-13, 13), (-7, 7), (-5, 5), (-9, 9)]
# [(-15, 15), (-12, 12), (-13, 13), (-7, 7), (-5, 5), (-9, 9), (-8, 8)]
# [(-15, 15), (-12, 12), (-13, 13), (-11, 11), (-5, 5), (-9, 9), (-8, 8), (-7, 7)]
# [(-19, 19), (-15, 15), (-13, 13), (-12, 12), (-5, 5), (-9, 9), (-8, 8), (-7, 7), (-11, 11)]
# [(-19, 19), (-15, 15), (-13, 13), (-12, 12), (-6, 6), (-9, 9), (-8, 8), (-7, 7), (-11, 11), (-5, 5)]
# [(-19, 19), (-15, 15), (-13, 13), (-12, 12), (-11, 11)]
# 21 10 26 31 16
# [(-21, 21), (-15, 15), (-19, 19), (-12, 12), (-11, 11), (-13, 13)]
# [(-21, 21), (-15, 15), (-19, 19), (-12, 12), (-11, 11), (-13, 13), (-10, 10)]
# [(-26, 26), (-21, 21), (-19, 19), (-15, 15), (-11, 11), (-13, 13), (-10, 10), (-12, 12)]
# ...

# %%
import sys
import heapq

N = int(sys.stdin.readline())
q = []
for _ in range(N):
    for n in map(int, sys.stdin.readline().split()):
        heapq.heappush(q, (-n, n))
    q = heapq.nsmallest(N, q)
heapq.heapify(q)
print(q[N-1][1])
