# %% [markdown]
# <a href="https://colab.research.google.com/github/Vulter3653/python/blob/main/%EB%B0%B1%EC%A4%80_9375_%ED%8C%A8%EC%85%98%EC%99%95_%EC%8B%A0%ED%95%B4%EB%B9%88_%EC%99%84%EB%A3%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input())

for _ in range(num):
  clo = []
  clo_uni = set()

  for x in range(int(input())):
    a,b=input().split()
    clo_uni.add(b)
    clo.append([a,b])
    print(clo)

  clo_uni = list(clo_uni)
  print(clo_uni)

  ans_li = []

  for x in range(len(clo_uni)):
    clo_num = 1
    for y in range(len(clo)):
      if clo[y][1] == clo_uni[x]:
        print(clo[y])
        clo_num += 1
    ans_li.append(clo_num)

  ans = 1
  for x in ans_li:
    ans *= x

  print(ans-1)
# Out:
# 2
# 3
# hat headgear
# [['hat', 'headgear']]
# sunglasses eyewear
# [['hat', 'headgear'], ['sunglasses', 'eyewear']]
# turban headgear
# [['hat', 'headgear'], ['sunglasses', 'eyewear'], ['turban', 'headgear']]
# ['eyewear', 'headgear']
# ['sunglasses', 'eyewear']
# ['hat', 'headgear']
# ['turban', 'headgear']
# 5
# 3
# mask face
# [['mask', 'face']]
# sunglasses face
# [['mask', 'face'], ['sunglasses', 'face']]
# makeup face
# [['mask', 'face'], ['sunglasses', 'face'], ['makeup', 'face']]
# ['face']
# ['mask', 'face']
# ['sunglasses', 'face']
# ['makeup', 'face']
# 3

# %%
num = int(input())

for _ in range(num):
  clo = []
  clo_uni = set()

  for x in range(int(input())):
    a,b=input().split()
    clo_uni.add(b)
    clo.append([a,b])

  clo_uni = list(clo_uni)

  ans_li = []

  for x in range(len(clo_uni)):
    clo_num = 1
    for y in range(len(clo)):
      if clo[y][1] == clo_uni[x]:
        clo_num += 1
    ans_li.append(clo_num)

  ans = 1
  for x in ans_li:
    ans *= x

  print(ans-1)
