# %% [markdown]
# <a href="https://colab.research.google.com/github/Vulter3653/python/blob/main/%EB%B0%B1%EC%A4%80_3058_%EC%A7%9D%EC%88%98%EB%A5%BC_%EC%B0%BE%EC%95%84%EB%9D%BC_%EC%99%84%EB%A3%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for _ in range(int(input())):
  data = list(map(int,input().split()))
  data.sort(reverse=True)
  ans = 0
  k = 0
  for x in data:
    if x%2 == 0:
      ans+=x
      k = x
  print(ans,k)
# Out:
# 2
# 1 2 3 4 5 6 7
# 12 2
# 13 78 39 42 54 93 86
# 260 42
