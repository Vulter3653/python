# %% [markdown]
# <a href="https://colab.research.google.com/github/Vulter3653/python/blob/main/%EB%B0%B1%EC%A4%80_1427_%EC%86%8C%ED%8A%B8%EC%9D%B8%EC%82%AC%EC%9D%B4%EB%93%9C_%EC%99%84%EB%A3%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for _ in range(4):
  a = list(input())
  print(a)
  a.sort(reverse=True)
  print(a)
  for x in a:
    print(x, end="")
# Out:
# 2143
# ['2', '1', '4', '3']
# ['4', '3', '2', '1']
# 4321999998999
# ['9', '9', '9', '9', '9', '8', '9', '9', '9']
# ['9', '9', '9', '9', '9', '9', '9', '9', '8']
# 99999999861423
# ['6', '1', '4', '2', '3']
# ['6', '4', '3', '2', '1']
# 64321500613009
# ['5', '0', '0', '6', '1', '3', '0', '0', '9']
# ['9', '6', '5', '3', '1', '0', '0', '0', '0']
# 965310000

# %%
a = list(input())
a.sort(reverse=True)
for x in a:
  print(x, end="")
