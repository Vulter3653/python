# %% [markdown]
# <a href="https://colab.research.google.com/github/Vulter3653/python/blob/main/%EB%B0%B1%EC%A4%80_2902_KMP%EB%8A%94_%EC%99%9C_KMP%EC%9D%BC%EA%B9%8C%3F_%EC%99%84%EB%A3%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
k = list(input().split('-'))
for x in k:
  print(x[0],end="")
# Out:
# Knuth-Morris-Pratt
# KMP

# %%
for _ in range(3):
  k = list(input().split('-'))
  for x in k:
    print(x[0],end="")
# Out:
# Knuth-Morris-Pratt
# KMPMirko-Slavko
# MSPasko-Patak
# PP
