# %% [markdown]
# <a href="https://colab.research.google.com/github/Vulter3653/python/blob/main/%EB%B0%B1%EC%A4%80_1316_%EA%B7%B8%EB%A3%B9_%EB%8B%A8%EC%96%B4_%EC%B2%B4%EC%BB%A4_%EC%99%84%EB%A3%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
output = 0
for i in range(int(input())):
  a = input()
  print(a)
  b = len(set(a))-1
  print(b)
  cnt = 0
  for x in range(len(a)-1):
    if a[x] != a[x+1]:
      print(a[x],a[x+1])
      cnt += 1
  if b == cnt:
    output += 1
  print(cnt)
  print(output)
# Out:
# 9
# aaa
# aaa
# 0
# 0
# 1
# aaazbz
# aaazbz
# 2
# a z
# z b
# b z
# 3
# 1
# babb
# babb
# 1
# b a
# a b
# 2
# 1
# aazz
# aazz
# 1
# a z
# 1
# 2
# azbz
# azbz
# 2
# a z
# z b
# b z
# 3
# 2
# aabbaa
# aabbaa
# 1
# a b
# b a
# 2
# 2
# abacc
# abacc
# 2
# a b
# b a
# a c
# 3
# 2
# aba
# aba
# 1
# a b
# b a
# 2
# 2
# zzaz
# zzaz
# 1
# z a
# a z
# 2
# 2

# %%
output = 0
for i in range(int(input())):
  a = input().strip()
  b = len(set(a))-1
  cnt = 0
  for x in range(len(a)-1):
    if a[x] != a[x+1]:
      cnt += 1
  if b == cnt:
    output += 1
print(output)
