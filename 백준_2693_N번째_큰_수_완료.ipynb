# %% [markdown]
# <a href="https://colab.research.google.com/github/Vulter3653/python/blob/main/%EB%B0%B1%EC%A4%80_2693_N%EB%B2%88%EC%A7%B8_%ED%81%B0_%EC%88%98_%EC%99%84%EB%A3%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for _ in range(int(input())):
  num = list(map(int,input().split()))
  num.sort()
  print(num[-3])
# Out:
# 4
# 1 2 3 4 5 6 7 8 9 1000
# 8
# 338 304 619 95 343 496 489 116 98 127
# 489
# 931 240 986 894 826 640 965 833 136 138
# 931
# 940 955 364 188 133 254 501 122 768 408
# 768
