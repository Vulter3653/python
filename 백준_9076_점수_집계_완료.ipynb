# %% [markdown]
# <a href="https://colab.research.google.com/github/Vulter3653/python/blob/main/%EB%B0%B1%EC%A4%80_9076_%EC%A0%90%EC%88%98_%EC%A7%91%EA%B3%84_%EC%99%84%EB%A3%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for _ in range(int(input())):
  score = list(map(int, input().split()))
  score.sort()
  if (score[3]-score[1])>=4:
    print("KIN")
  else:
    print(score[1]+score[2]+score[3])
# Out:
# 5
# 10 8 5 7 9
# 24
# 10 9 10 9 5
# 28
# 10 3 5 9 10
# KIN
# 1 2 3 6 9
# KIN
# 1 2 3 6 9
# KIN
