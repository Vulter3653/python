# %% [markdown]
# <a href="https://colab.research.google.com/github/Vulter3653/python/blob/main/%EB%B0%B1%EC%A4%80_3040_%EB%B0%B1%EC%84%A4_%EA%B3%B5%EC%A3%BC%EC%99%80_%EC%9D%BC%EA%B3%B1_%EB%82%9C%EC%9F%81%EC%9D%B4_%EC%99%84%EB%A3%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for _ in range(2):
  seven_li = []
  for _ in range(9):
      seven_li.append(int(input()))
  print(seven_li)
  print(sum(seven_li)-100)

  flag = False

  for x in range(9):
    for y in range(x+1,9):
      print(seven_li[x],seven_li[y])
      if seven_li[x]+seven_li[y] == (sum(seven_li)-100):
        seven_li.remove(seven_li[y])
        seven_li.remove(seven_li[x])
        flag = True
        break
    if flag == True:
      break

  print(seven_li)
  for k in seven_li:
    print(k)
  print("\n")
# Out:
# 7
# 8
# 10
# 13
# 15
# 19
# 20
# 23
# 25
# [7, 8, 10, 13, 15, 19, 20, 23, 25]
# 40
# 7 8
# 7 10
# 7 13
# 7 15
# 7 19
# 7 20
# 7 23
# 7 25
# 8 10
# 8 13
# 8 15
# 8 19
# 8 20
# 8 23
# 8 25
# 10 13
# 10 15
# 10 19
# 10 20
# 10 23
# 10 25
# 13 15
# 13 19
# 13 20
# 13 23
# 13 25
# 15 19
# 15 20
# 15 23
# 15 25
# [7, 8, 10, 13, 19, 20, 23]
# 7
# 8
# 10
# 13
# 19
# 20
# 23
#
#
# 8
# 6
# 5
# 1
# 37
# 30
# 28
# 22
# 36
# [8, 6, 5, 1, 37, 30, 28, 22, 36]
# 73
# 8 6
# 8 5
# 8 1
# 8 37
# 8 30
# 8 28
# 8 22
# 8 36
# 6 5
# 6 1
# 6 37
# 6 30
# 6 28
# 6 22
# 6 36
# 5 1
# 5 37
# 5 30
# 5 28
# 5 22
# 5 36
# 1 37
# 1 30
# 1 28
# 1 22
# 1 36
# 37 30
# 37 28
# 37 22
# 37 36
# [8, 6, 5, 1, 30, 28, 22]
# 8
# 6
# 5
# 1
# 30
# 28
# 22

# %%
seven_li = []
for _ in range(9):
  seven_li.append(int(input()))

flag = False

for x in range(9):
  for y in range(x+1,9):
    if seven_li[x]+seven_li[y] == (sum(seven_li)-100):
      seven_li.remove(seven_li[y])
      seven_li.remove(seven_li[x])
      flag = True
      break
  if flag == True:
    break

for k in seven_li:
  print(k)
